# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Example: Load your dataset
# Replace 'your_dataset.csv' with the path to your data file
path = '/home/habib/Downloads/equation_train_data/final_data/'
files = os.listdir(path)
df = pd.DataFrame()
for file in files:
    if file.endswith('.json'):  # Ensure you're only reading JSON files
        read_df = pd.read_json(os.path.join(path, file))
        df = pd.concat([df, read_df], ignore_index=True)
print(df.head())

# Remove all rows have waf = 1
df = df[df['waf'] != 1]

print(df.head())

# df = pd.read_json('/home/habib/Downloads/equation_train_data/final_data/ran_s1_op_20_final_version.json')

# Features (independent variables)
X = df[['std_invalid_page_count', 'op', 'ssd_size']]  # Ensure these columns exist in your dataset

# Target variable (dependent variable)
y = df['waf']

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Extract coefficients and intercept
coefficients = model.coef_  # [alpha, beta, gamma]
intercept = model.intercept_  # delta

# Display results
print("Coefficients (alpha, beta, gamma):", coefficients)
print("Intercept (delta):", intercept)

# Test the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
#    std_erase_count  std_invalid_page_count  op        type  ssd_size  waf
# 0              0.0               39.775155  20  sequential       2.4  1.0
# 1              0.0               41.093211  20  sequential       2.4  1.0
# 2              0.0               42.362494  20  sequential       2.4  1.0
# 3              0.0               43.569003  20  sequential       2.4  1.0
# 4              0.0               44.655118  20  sequential       2.4  1.0
#     std_erase_count  std_invalid_page_count  op        type  ssd_size
# 11         0.292038               42.800627  20  sequential       2.4  \
# 12         0.324189               42.445300  20  sequential       2.4
# 13         0.353128               42.054365  20  sequential       2.4
# 14         0.380164               41.673052  20  sequential       2.4
# 15         0.407500               41.320385  20  sequential       2.4
#
#          waf
# 11  1.000241
# 12  1.000948
# 13  1.002118
# 14  1.004076
# 15  1.006385
# ...

# %%
# Create a graph to visualize the relation between waf and std invalid page count
import matplotlib.pyplot as plt
# take the data for type random
df = df[df['type'] == 'random']

plt.scatter(df['std_invalid_page_count'], df['waf'])
plt.xlabel('std_invalid_page_count')
plt.ylabel('waf')
plt.title('std_invalid_page_count vs waf')
plt.show()

# %%
# Create a graph to visualize the relation between waf and std invalid page count
import matplotlib.pyplot as plt
# take the data for type random
df = df[df['type'] == 'random']

plt.scatter(df['std_erase_count'], df['waf'])
plt.xlabel('std_erase_count')
plt.ylabel('waf')
plt.title('std_erase_count vs waf')
plt.show()

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
# Create a graph to visualize the relation between waf and std invalid page count
import matplotlib.pyplot as plt

# Example: Load your dataset
# Replace 'your_dataset.csv' with the path to your data file
path = '/home/habib/Downloads/equation_train_data/final_data/'
files = os.listdir(path)
df = pd.DataFrame()
for file in files:
    if file.endswith('.json'):  # Ensure you're only reading JSON files
        read_df = pd.read_json(os.path.join(path, file))
        # create line graph for each file relation between waf and std_invalid_page_count add the title of the file
        # Add all line in single graph for comparison
        # if file name contain ran plot in one graph for seq create another graph for ran create another graph 
        if 'ran' in file:
            plt.plot(read_df['std_invalid_page_count'], read_df['waf'], label=file)
plt.xlabel('std_invalid_page_count')
plt.ylabel('waf')
plt.title('std_invalid_page_count vs waf')
plt.legend()
plt.show()

        
#         plt.plot(read_df['std_invalid_page_count'], read_df['waf'], label=file)
# plt.xlabel('std_invalid_page_count')
# plt.ylabel('waf')
# plt.title('std_invalid_page_count vs waf')
# plt.legend()
# plt.show()

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
# Create a graph to visualize the relation between waf and std invalid page count
import matplotlib.pyplot as plt

# Example: Load your dataset
# Replace 'your_dataset.csv' with the path to your data file
path = '/home/habib/Downloads/equation_train_data/final_data/'
files = os.listdir(path)
df = pd.DataFrame()
for file in files:
    if file.endswith('.json'):  # Ensure you're only reading JSON files
        read_df = pd.read_json(os.path.join(path, file))
        # create line graph for each file relation between waf and std_invalid_page_count add the title of the file
        # Add all line in single graph for comparison
        # if file name contain ran plot in one graph for seq create another graph for ran create another graph 
        if 'seq' in file:
            plt.plot(read_df['std_invalid_page_count'], read_df['waf'], label=file)
plt.xlabel('std_invalid_page_count')
plt.ylabel('waf')
plt.title('std_invalid_page_count vs waf')
plt.legend()
plt.show()

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
# Create a graph to visualize the relation between waf and std invalid page count
import matplotlib.pyplot as plt

# Example: Load your dataset
# Replace 'your_dataset.csv' with the path to your data file
path = '/home/habib/Downloads/equation_train_data/final_data/'
files = os.listdir(path)
df = pd.DataFrame()
for file in files:
    if file.endswith('.json'):  # Ensure you're only reading JSON files
        read_df = pd.read_json(os.path.join(path, file))
        # create line graph for each file relation between waf and std_invalid_page_count add the title of the file
        # Add all line in single graph for comparison
        # if file name contain ran plot in one graph for seq create another graph for ran create another graph 
        if 'zipf' in file:
            plt.plot(read_df['std_invalid_page_count'], read_df['waf'], label=file)
plt.xlabel('std_invalid_page_count')
plt.ylabel('waf')
plt.title('std_invalid_page_count vs waf')
plt.legend()
plt.show()
