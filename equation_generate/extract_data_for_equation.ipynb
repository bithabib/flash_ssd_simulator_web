# %% [markdown]
# ## Trace: Random, Dataplacement: S1, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s1_op_20/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s1_op_20_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S2, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s2_op_20/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s2_op_20_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S3, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s3_op_20/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s3_op_20_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S4, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s4_op_20/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s4_op_20_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S5, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s5_op_20/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s5_op_20_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S6, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %% [markdown]
# # Trace: Seq, Dataplacement: S1, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s1_op_20/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s1_op_20_final_version.json')

# %% [markdown]
# # Trace: Seq, Dataplacement: S2, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s2_op_20/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s2_op_20_final_version.json')

# %% [markdown]
# # Trace: Seq, Dataplacement: S3, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s3_op_20/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s3_op_20_final_version.json')

# %% [markdown]
# # Trace: Seq, Dataplacement: S4, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s4_op_20/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s4_op_20_final_version.json')

# %% [markdown]
# # Trace: Seq, Dataplacement: S5, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %% [markdown]
# # Trace: Seq, Dataplacement: S6, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %% [markdown]
# # Trace: Zipf, Dataplacement: S1, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s1_op_20/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s1_op_20_final_version.json')

# %% [markdown]
# # Trace: Zipf, Dataplacement: S2, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s2_op_20/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s2_op_20_final_version.json')

# %% [markdown]
# # Trace: Zipf, Dataplacement: S3, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s3_op_20/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s3_op_20_final_version.json')

# %% [markdown]
# # Trace: Zipf, Dataplacement: S4, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s4_op_20/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s4_op_20_final_version.json')

# %% [markdown]
# # Trace: Zipf, Dataplacement: S5, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s5_op_20/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 20,
        'type': 'ran_s3',
        'ssd_size': 2.4,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s5_op_20_final_version.json')

# %% [markdown]
# # Trace: Zipf, Dataplacement: S6, OP: 20, SSD Initial: 80% full, SSD Size: 2.4gb

# %% [markdown]
# # Trace: Random, Dataplacement: S1, OP: 15, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s1_op_15/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 15,
        'type': 'ran_s3',
        'ssd_size': 2.55,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s1_op_15_final_version.json')

# %% [markdown]
# # Trace: Random, Dataplacement: S6, OP: 10, SSD Initial: 80% full, SSD Size: 2.4gb

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/ran_s1_op_10/'
waf_s3_op_20 = pd.read_json(path + 'rand_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween rand_trace.log_ and .json first take all file containing rand_trace.log_
files = [f for f in files if 'rand_trace.log_' in f]
# sort the files by number inbetween rand_trace.log_ and .json
files = [f for f in files if f.split('rand_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('rand_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('rand_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 10,
        'type': 'ran_s3',
        'ssd_size': 2.70,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'ran_s1_op_10_final_version.json')

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s1_op_15/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 15,
        'type': 'ran_s3',
        'ssd_size': 2.55,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s1_op_15_final_version.json')

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd


path = '/home/habib/Downloads/equation_train_data/seq_s1_op_10/'
waf_s3_op_20 = pd.read_json(path + 'seq_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween seq_trace.log_ and .json first take all file containing seq_trace.log_
files = [f for f in files if 'seq_trace.log_' in f]
# sort the files by number inbetween seq_trace.log_ and .json
files = [f for f in files if f.split('seq_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('seq_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('seq_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 10,
        'type': 'ran_s3',
        'ssd_size': 2.70,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'seq_s1_op_10_final_version.json')

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s1_op_15/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 15,
        'type': 'ran_s3',
        'ssd_size': 2.55,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s1_op_15_final_version.json')

# %%
# Read all the file in a folder in specific order
import os
import json
import numpy as np
import pandas as pd

path = '/home/habib/Downloads/equation_train_data/zipf_s1_op_10/'
waf_s3_op_20 = pd.read_json(path + 'zipf_trace.log_waf.json')
files = os.listdir(path)
# sort the files by number inbetween zipf_trace.log_ and .json first take all file containing zipf_trace.log_
files = [f for f in files if 'zipf_trace.log_' in f]
# sort the files by number inbetween zipf_trace.log_ and .json
files = [f for f in files if f.split('zipf_trace.log_')[1].split('.json')[0].isdigit()]
files.sort(key=lambda x: int(x.split('zipf_trace.log_')[1].split('.json')[0]))

# read file one by one using loop 
ran_s3_op_20_final_version = []
for file in files:
    interger_value = int(int(file.split('zipf_trace.log_')[1].split('.json')[0])/10)
    waf_index = interger_value//128
    ran_s3_op_20 = pd.read_json(path+file)
    ran_s3_op_20_erase_count = ran_s3_op_20.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
    ran_s3_op_20_invalid_page_count = ran_s3_op_20.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
    ran_s3_op_20_erase_count_std = np.std(ran_s3_op_20_erase_count['erase_count'])
    ran_s3_op_20_invalid_page_count_std = np.std(ran_s3_op_20_invalid_page_count['invalid_pages'])
    final_json = {
        'std_erase_count': ran_s3_op_20_erase_count_std,
        'std_invalid_page_count': ran_s3_op_20_invalid_page_count_std,
        'op': 15,
        'type': 'ran_s3',
        'ssd_size': 2.70,
        'waf': waf_s3_op_20['waf'][waf_index]
        }
    ran_s3_op_20_final_version.append(final_json)

# convert the list to dataframe
ran_s3_op_20_final_version = pd.DataFrame(ran_s3_op_20_final_version)
# save the dataframe as json
ran_s3_op_20_final_version.to_json(path+'zipf_s1_op_10_final_version.json')
